# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iris=pd.read_csv(r'C:\Users\Shruti Rani\Downloads\iris.data',header=None)

# %%
print(iris)
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       150 non-null    float64
#  1   1       150 non-null    float64
#  2   2       150 non-null    float64
#  3   3       150 non-null    float64
#  4   4       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.isnull().sum()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# dtype: int64

# %%
iris0=iris.rename(columns={0:"sepal length"},inplace=True)
iris1=iris.rename(columns={1:"sepal width"},inplace=True)
iris2=iris.rename(columns={2:"petal length"},inplace=True)
iris3=iris.rename(columns={3:"petal width"},inplace=True)
iris4=iris.rename(columns={4:"species"},inplace=True)

# %%
print(iris)
# Out:
#      sepal length  sepal width  petal length  petal width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris["species"].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: species, dtype: int64

# %%
fig=plt.figure()
ax1=fig.add_subplot(2,2,1)
ax2=fig.add_subplot(2,2,2)
ax3=fig.add_subplot(2,2,3)
ax4=fig.add_subplot(2,2,4)
ax1.hist(iris["sepal length"],color="red")
ax2.hist(iris["sepal length"],color="green")
ax3.hist(iris["sepal length"],color="cyan")
ax4.hist(iris["sepal length"],color="orange")
fig.set_figheight(10)
fig.set_figwidth(15)
plt.show()

# %%
sns.pairplot(data=iris,kind="scatter")

# %%
corr=iris.corr()
plt.figure(figsize=(5,4))
sns.heatmap(corr,annot=True,vmin=-1.0,cmap="mako")
plt.title("correlation")
plt.show()
# Out:
# C:\Users\Shruti Rani\AppData\Local\Temp\ipykernel_5108\1393249308.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=iris.corr()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
train,test=train_test_split(iris,test_size=0.25)

# %%
train
# Out:
#      sepal length  sepal width  petal length  petal width          species
# 52            6.9          3.1           4.9          1.5  Iris-versicolor
# 6             4.6          3.4           1.4          0.3      Iris-setosa
# 7             5.0          3.4           1.5          0.2      Iris-setosa
# 85            6.0          3.4           4.5          1.6  Iris-versicolor
# 72            6.3          2.5           4.9          1.5  Iris-versicolor
# ..            ...          ...           ...          ...              ...
# 99            5.7          2.8           4.1          1.3  Iris-versicolor
# 65            6.7          3.1           4.4          1.4  Iris-versicolor
# 76            6.8          2.8           4.8          1.4  Iris-versicolor
# 48            5.3          3.7           1.5          0.2      Iris-setosa
# 111           6.4          2.7           5.3          1.9   Iris-virginica
#
# [112 rows x 5 columns]

# %%
test
# Out:
#      sepal length  sepal width  petal length  petal width          species
# 10            5.4          3.7           1.5          0.2      Iris-setosa
# 32            5.2          4.1           1.5          0.1      Iris-setosa
# 56            6.3          3.3           4.7          1.6  Iris-versicolor
# 11            4.8          3.4           1.6          0.2      Iris-setosa
# 13            4.3          3.0           1.1          0.1      Iris-setosa
# 93            5.0          2.3           3.3          1.0  Iris-versicolor
# 20            5.4          3.4           1.7          0.2      Iris-setosa
# 43            5.0          3.5           1.6          0.6      Iris-setosa
# 124           6.7          3.3           5.7          2.1   Iris-virginica
# 84            5.4          3.0           4.5          1.5  Iris-versicolor
# 68            6.2          2.2           4.5          1.5  Iris-versicolor
# ...

# %%
train_x=train[['sepal length','sepal width','petal length','petal width']]

# %%
train_y=train.species

# %%
train_x
# Out:
#      sepal length  sepal width  petal length  petal width
# 52            6.9          3.1           4.9          1.5
# 6             4.6          3.4           1.4          0.3
# 7             5.0          3.4           1.5          0.2
# 85            6.0          3.4           4.5          1.6
# 72            6.3          2.5           4.9          1.5
# ..            ...          ...           ...          ...
# 99            5.7          2.8           4.1          1.3
# 65            6.7          3.1           4.4          1.4
# 76            6.8          2.8           4.8          1.4
# 48            5.3          3.7           1.5          0.2
# 111           6.4          2.7           5.3          1.9
#
# [112 rows x 4 columns]

# %%
train_y
# Out:
# 52     Iris-versicolor
# 6          Iris-setosa
# 7          Iris-setosa
# 85     Iris-versicolor
# 72     Iris-versicolor
#             ...
# 99     Iris-versicolor
# 65     Iris-versicolor
# 76     Iris-versicolor
# 48         Iris-setosa
# 111     Iris-virginica
# Name: species, Length: 112, dtype: object

# %%
test_x=test[['sepal length','sepal width','petal length','petal width']]
test_y=test.species

# %%
from sklearn import svm
from sklearn.tree import DecisionTreeClassifier

# %%
model=svm.SVC()

# %%
model.fit(train_x,train_y)
pred=model.predict(test_x)

# %%
from sklearn import metrics

# %%
metrics.accuracy_score(pred,test_y)
# Out:
# 1.0

# %%
model=DecisionTreeClassifier()

# %%
model.fit(train_x,train_y)
# Out:
# DecisionTreeClassifier()

# %%
pred=model.predict(test_x)

# %%
metrics.accuracy_score(pred,test_y)
# Out:
# 0.9473684210526315
